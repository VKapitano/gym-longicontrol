# %% [markdown]
# This notebook is used to control the model training in Colab and visualize the results. First you need to mount Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install numpy==1.26.4 gym==0.25.2

# %%
# !pip install torch==2.5.1
# Out:
# ...
#   Using cached torch-2.5.1-cp312-cp312-manylinux1_x86_64.whl.metadata (28 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 71.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# You need to download the gym_longicontrol-master folder from Github and upload it to Drive. Then you can change the current directory so that it points to your gym_longicontrol-master folder on Drive.

# %%
import os

folder_path = '/content/drive/MyDrive/Colab Notebooks'

# %%
path = os.path.join(folder_path, 'gym_longicontrol-master')
os.chdir(path)

# %% [markdown]
# Installing the gym_longicontrol python library. Python scripts from the folder are installed as packages.

# %%
pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/Colab%20Notebooks/gym_longicontrol-master
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for gym_longicontrol
# ...

# %% [markdown]
# Installing Pyglet which is required for visualization.

# %%
# !pip install pyglet
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 33.7 MB/s eta 0:00:00
# ...

# %%
path = os.path.join(folder_path, 'gym_longicontrol-master/rl/pytorch')
os.chdir(path)

# %% [markdown]
# In order to get new .pkl file from car model data , the following comented lines need to be run. If existing .pkl file works properly there is no need for it.

# %%
#path = os.path.join(folder_path, 'gym_longicontrol/gym_longicontrol/envs')
#os.chdir(path)

# %%
#import car

#car_id = 'BMW_electric_i3_2014'
#car.create_power_estimator(car_id)

# %% [markdown]
# Now we can start model training with some parameters. If we want to train the model from the beggining, we need to send save_id. If we have a partially trained model we can continue train it by specifying load_id. The -rec argument is optional, it is used for visualizate steps during training (in mp4 format).

# %%
path = os.path.join(folder_path, 'gym_longicontrol-master/rl/pytorch')
os.chdir(path)

# %%
# !python main.py --num_epochs 10 --num_steps_per_epoch 50 --save_id 7
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
# ...

# %% [markdown]
# In order for Pyglet to function properly in Colab, an virtual monitor should be installed.

# %%
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.15).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ...

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %% [markdown]
# We can visualize the results on a specific case. The video will be saved in mp4 format. We need to give -vis and -rec arguments and specify load_id.

# %%
# !python main.py --load_id 7 -vis -rec
# Out:
# Streaming output truncated to the last 5000 lines.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# /usr/local/lib/python3.12/dist-packages/gym/core.py:49: DeprecationWarning: WARN: You are calling render method, but you didn't specified the argument render_mode at environment initialization. To maintain backward compatibility, the environment will render in human mode.
# If you want to render in human mode, initialize the environment in this way: gym.make('EnvName', render_mode='human') and don't call the render method.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# round:  1303
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# ...
